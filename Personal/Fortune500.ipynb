# %% [markdown]
# # Fortune 500 2017

# %%
import matplotlib.pyplot as plt 
import metapack as mp
import pandas as pd
import numpy as np
import seaborn as sns
sns.set(color_codes=True)
# %matplotlib inline

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/pbpex55feoij3hqh53evzcnmbazvxp')
df.to_csv('fortune500-2017.csv')

# %%
df.head().T
# Out:
#                                                          0  \
# Rank                                                     1
# Title                                              Walmart
# Website                             http://www.walmart.com
# Employees                                          2300000
# Sector                                           Retailing
# Industry                             General Merchandisers
# Hqlocation                                 Bentonville, AR
# Hqaddr                                 702 S.W. Eighth St.
# Hqcity                                         Bentonville
# Hqstate                                                 AR
# Hqzip                                                72716
# Hqtel                                         479-273-4000
# Ceo                                    C. Douglas McMillon
# Ceo-title    President, Chief Executive Officer & Director
# Address         702 S.W. Eighth St., Bentonville, AR 72716
# ...

# %%
dfs = df[['Title','Employees','Revenues','Profits','Assets','Totshequity']].copy()

# %%
dfs.Profits.sum()/dfs.Revenues.sum()
# Out:
# 0.0738013602331942

# %%
dfs.Profits.sum()/1000 # profits in millions, result in billions
# Out:
# 889.7398999999999

# %%
(2017-1985) + 900
# Out:
# 932

# %%
dfs['pmargin'] = dfs.Profits/dfs.Revenues

# %%
dfs['pmargin'].hist(bins=20)

# %%
dfs['Revenues'].hist(bins=20)

# %%
dfs.sort_values('pmargin',ascending=False).head(20)
# Out:
#                            Title  Employees  Revenues  Profits  Assets  \
# 309                         eBay      12600      8979   7266.0   23847
# 147                 Altria Group       8300     19337  14239.0   45932
# 280         Baxter International      48000     10163   4965.0   15546
# 222            Reynolds American       5525     12503   6073.0   51095
# 464                     Symantec      11000      5568   2488.0   11767
# 91               Gilead Sciences       9000     30390  13501.0   56977
# 186                         Visa      14200     15082   5991.0   64035
# 297                      Corning      40700      9390   3695.0   27899
# 266                   Mastercard      11900     10776   4059.0   18675
# 458                   S&P Global      20000      5661   2106.0    8669
# 97                      Facebook      17048     27638  10217.0   64961
# 476         Simon Property Group       4050      5435   1838.9   31104
# ...

# %%
fig = plt.figure()
ax = plt.gca()

ax.set_yscale('log')
ax.set_xscale('log')

dfs.plot(ax=ax, kind='scatter', x='pmargin', y='Revenues');
